# %%
import geopandas as gpd
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
shapefile = 'ne_110m_admin_0_countries.shp'

#Read shapefile using Geopandas
gdf = gpd.read_file(shapefile)[['ADMIN', 'ADM0_A3', 'geometry']]

#Rename columns.
gdf.columns = ['country', 'country_code', 'geometry']
gdf
# Out:
#                                  country country_code  \
# 0                                   Fiji          FJI
# 1            United Republic of Tanzania          TZA
# 2                         Western Sahara          SAH
# 3                                 Canada          CAN
# 4               United States of America          USA
# 5                             Kazakhstan          KAZ
# 6                             Uzbekistan          UZB
# 7                       Papua New Guinea          PNG
# 8                              Indonesia          IDN
# 9                              Argentina          ARG
# 10                                 Chile          CHL
# 11      Democratic Republic of the Congo          COD
# 12                               Somalia          SOM
# 13                                 Kenya          KEN
# 14                                 Sudan          SDN
# 15                                  Chad          TCD
# 16                                 Haiti          HTI
# 17                    Dominican Republic          DOM
# 18                                Russia          RUS
# 19                           The Bahamas          BHS
# 20                      Falkland Islands          FLK
# 21                                Norway          NOR
# 22                             Greenland          GRL
# 23   French Southern and Antarctic Lands          ATF
# 24                            East Timor          TLS
# 25                          South Africa          ZAF
# 26                               Lesotho          LSO
# 27                                Mexico          MEX
# 28                               Uruguay          URY
# 29                                Brazil          BRA
# ..                                   ...          ...
# 147                          Philippines          PHL
# 148                             Malaysia          MYS
# 149                               Brunei          BRN
# 150                             Slovenia          SVN
# 151                              Finland          FIN
# 152                             Slovakia          SVK
# 153                              Czechia          CZE
# 154                              Eritrea          ERI
# 155                                Japan          JPN
# 156                             Paraguay          PRY
# 157                                Yemen          YEM
# 158                         Saudi Arabia          SAU
# 159                           Antarctica          ATA
# 160                      Northern Cyprus          CYN
# 161                               Cyprus          CYP
# 162                              Morocco          MAR
# 163                                Egypt          EGY
# 164                                Libya          LBY
# 165                             Ethiopia          ETH
# 166                             Djibouti          DJI
# 167                           Somaliland          SOL
# 168                               Uganda          UGA
# 169                               Rwanda          RWA
# 170               Bosnia and Herzegovina          BIH
# 171                            Macedonia          MKD
# 172                   Republic of Serbia          SRB
# 173                           Montenegro          MNE
# 174                               Kosovo          KOS
# 175                  Trinidad and Tobago          TTO
# 176                          South Sudan          SDS
#
#                                               geometry
# 0    (POLYGON ((180 -16.06713266364245, 180 -16.555...
# 1    POLYGON ((33.90371119710453 -0.950000000000000...
# 2    POLYGON ((-8.665589565454809 27.65642588959236...
# 3    (POLYGON ((-122.84 49.00000000000011, -122.974...
# 4    (POLYGON ((-122.84 49.00000000000011, -120 49....
# 5    POLYGON ((87.35997033076265 49.21498078062912,...
# 6    POLYGON ((55.96819135928291 41.30864166926936,...
# 7    (POLYGON ((141.0002104025919 -2.60015105551566...
# 8    (POLYGON ((141.0002104025919 -2.60015105551566...
# 9    (POLYGON ((-68.63401022758323 -52.636370458874...
# 10   (POLYGON ((-68.63401022758323 -52.636370458874...
# 11   POLYGON ((29.33999759290035 -4.499983412294093...
# 12   POLYGON ((41.58513 -1.68325, 40.993 -0.85829, ...
# 13   POLYGON ((39.20222 -4.67677, 37.7669 -3.67712,...
# 14   POLYGON ((24.56736901215209 8.229187933785468,...
# 15   POLYGON ((23.83766000000014 19.58047000000011,...
# 16   POLYGON ((-71.71236141629296 19.71445587816736...
# 17   POLYGON ((-71.70830481635805 18.04499705654609...
# 18   (POLYGON ((178.7253 71.0988, 180.0000000000001...
# 19   (POLYGON ((-78.98 26.79, -78.51000000000001 26...
# 20   POLYGON ((-61.2 -51.85, -60 -51.25, -59.15 -51...
# 21   (POLYGON ((15.14282 79.67431000000001, 15.5225...
# 22   POLYGON ((-46.76379 82.62796, -43.40644 83.225...
# 23   POLYGON ((68.935 -48.62500000000001, 69.58 -48...
# 24   POLYGON ((124.9686824891162 -8.892790215697083...
# 25   POLYGON ((16.34497684089524 -28.5767050106977,...
# 26   POLYGON ((28.97826256685724 -28.95559661226171...
# 27   POLYGON ((-117.1277599999999 32.53533999999996...
# 28   POLYGON ((-57.62513342958296 -30.2162948544542...
# 29   POLYGON ((-53.37366166849824 -33.7683777809007...
# ..                                                 ...
# 147  (POLYGON ((120.8338961121466 12.70449616134243...
# 148  (POLYGON ((100.0857568705271 6.464489447450291...
# 149  POLYGON ((115.4507104838698 5.447729803891534,...
# 150  POLYGON ((13.80647545742153 46.50930613869122,...
# 151  POLYGON ((28.59192955904319 69.06477692328666,...
# 152  POLYGON ((22.55813764821176 49.08573802346714,...
# 153  POLYGON ((15.01699588385867 51.10667409932158,...
# 154  POLYGON ((36.42951000000005 14.42211000000003,...
# 155  (POLYGON ((141.884600864835 39.18086456965148,...
# 156  POLYGON ((-58.16639238140805 -20.1767009416536...
# 157  POLYGON ((52.00000980002224 19.00000336351606,...
# 158  POLYGON ((34.95603722508426 29.35655467377885,...
# 159  (POLYGON ((-48.66061601418252 -78.047018731598...
# 160  POLYGON ((32.73178022637745 35.14002594658844,...
# 161  POLYGON ((32.73178022637745 35.14002594658844,...
# 162  POLYGON ((-2.169913702798624 35.16839630791668...
# 163  POLYGON ((36.86622999999997 22, 32.89999999999...
# 164  POLYGON ((25 22, 25.00000000000011 20.00304000...
# 165  POLYGON ((47.78942 8.003, 44.96360000000001 5....
# 166  POLYGON ((42.35156000000012 12.54223000000013,...
# 167  POLYGON ((48.94820475850985 11.41061728169797,...
# 168  POLYGON ((33.90371119710453 -0.950000000000000...
# 169  POLYGON ((30.41910485201925 -1.134659112150416...
# 170  POLYGON ((18.55999999999995 42.64999999999998,...
# 171  POLYGON ((22.38052575042459 42.32025950781509,...
# 172  POLYGON ((18.82982479287395 45.90887235802529,...
# 173  POLYGON ((20.07070000000005 42.58863000000008,...
# 174  POLYGON ((20.59024654668023 41.85540891928363,...
# 175  POLYGON ((-61.68000000000001 10.76, -61.105 10...
# 176  POLYGON ((30.83385242171543 3.509171604222463,...
#
# [177 rows x 3 columns]

# %%
print(gdf[gdf['country_code'] == 'USA'])
#Drop row corresponding to 'Antarctica'
gdf = gdf.drop(gdf.index[159])
# Out:
#                     country country_code  \
# 4  United States of America          USA
#
#                                             geometry
# 4  (POLYGON ((-122.84 49.00000000000011, -120 49....

# %%
import pandas as pd

datafile = 'unicorn.csv'

#Read csv file using pandas
df = pd.read_csv(datafile)

df
# Out:
#                        Company  Valuation                      Category  \
# 0                      17zuoye       1000  Internet Software & Services
# 1                      23andMe       1615                    Healthcare
# 2                    4Paradigm       1200  Internet Software & Services
# 3                     9f Group       1000                       Fintech
# 4                    About You       1000                    E-commerce
# 5      ACORN OakNorth Holdings       2300                       Fintech
# 6                      Actifio       1300                Data Analytics
# 7     Adaptive Biotechnologies       1000                    Healthcare
# 8                       Affirm       1790                       Fintech
# 9                      Afiniti       1600  Internet Software & Services
# 10             Age of Learning       1000  Internet Software & Services
# 11                   Aihuishou       1500                    E-commerce
# 12                  Aijia Life       1000                    E-commerce
# 13                      Airbnb      29252                    E-commerce
# 14                    Airtable       1100  Internet Software & Services
# 15                    Allbirds       1400                    E-commerce
# 16                   AppDirect       1000  Internet Software & Services
# 17                    AppLovin       2000  Internet Software & Services
# 18                  Apus Group       1000                         Other
# 19                       Asana       1500  Internet Software & Services
# 20                   Atom Bank       1249                       Fintech
# 21                Auris Health       1014                    Healthcare
# 22                 Auto1 Group       3539                    E-commerce
# 23         Automation Anywhere       2600  Internet Software & Services
# 24                  Automattic       1242  Internet Software & Services
# 25                Avaloq Group       1008                       Fintech
# 26                       Avant       1896                       Fintech
# 27                 AvidXchange       1244                       Fintech
# 28                      BeiBei       1000                    E-commerce
# 29                BenevolentAI       2100                    Healthcare
# ..                         ...        ...                           ...
# 279                   VistaJet       2500                     On-Demand
# 280      Viva Republica (Toss)       1200                       Fintech
# 281                  Vox Media       1000                         Media
# 282                     WalkMe       1000  Internet Software & Services
# 283               Warby Parker       1750                    E-commerce
# 284                  We Doctor       5500                    Healthcare
# 285                     WeWork      47000                         Other
# 286                       Wish       3000                    E-commerce
# 287             Woowa Brothers       2600                    E-commerce
# 288                Xiaohongshu       3000                    E-commerce
# 289                    XiaoZhu       1000                    E-commerce
# 290               XPeng Motors       3654                     Auto Tech
# 291               Yello Mobile       4000                         Other
# 292                  YH Global       1000                         Other
# 293               Yidian Zixun       1000                         Media
# 294                    Yijiupi       1100                    E-commerce
# 295            YITU Technology       2365  Internet Software & Services
# 296                      Yixia       1000                        Social
# 297              Youxia Motors       3350                     Auto Tech
# 298                  Yuanfudao       3000  Internet Software & Services
# 299                   Zenefits       2088                       Fintech
# 300                Zeta Global       1300  Internet Software & Services
# 301                   Zhaogang       1000                    E-commerce
# 302                      Zhihu       2500  Internet Software & Services
# 303               ZipRecruiter       1000  Internet Software & Services
# 304                     ZocDoc       1769                    Healthcare
# 305                     Zomato       2000                        Social
# 306  Zoom Video Communications       1000  Internet Software & Services
# 307                       Zoox       3200                     Auto Tech
# 308                 Zume Pizza       2250                     On-Demand
#
#             Country  Funding  \
# 0             China    385.0
# 1     United States    794.0
# 2             China    145.0
# 3             China    178.0
# 4           Germany    300.0
# 5    United Kingdom    550.0
# 6     United States    308.0
# 7     United States    416.0
# 8     United States    725.0
# 9     United States    162.0
# 10    United States    182.0
# 11            China    278.0
# 12            China    146.0
# 13    United States   4398.0
# 14    United States    163.0
# 15    United States     78.0
# 16    United States    250.0
# 17    United States   1385.0
# 18            China    116.0
# 19    United States    212.0
# 20   United Kingdom    514.0
# 21    United States    733.0
# 22          Germany   1064.0
# 23    United States    550.0
# 24    United States    193.0
# 25      Switzerland    300.0
# 26    United States   1719.0
# 27    United States    574.0
# 28            China    224.0
# 29   United Kingdom    256.0
# ..              ...      ...
# 279           Malta      NaN
# 280     South Korea    242.0
# 281   United States    325.0
# 282   United States    218.0
# 283   United States    291.0
# 284           China   1036.0
# 285   United States   6461.0
# 286   United States    719.0
# 287     South Korea    458.0
# 288           China    418.0
# 289           China    500.0
# 290           China   1343.0
# 291     South Korea    216.0
# 292           China    182.0
# 293           China    176.0
# 294           China    367.0
# 295           China    355.0
# 296           China    775.0
# 297           China   1326.0
# 298           China    544.0
# 299   United States    584.0
# 300   United States    380.0
# 301           China    361.0
# 302           China    502.0
# 303   United States    219.0
# 304   United States    226.0
# 305           India    374.0
# 306   United States    142.0
# 307   United States    790.0
# 308   United States    446.0
#
#                                              Investors
# 0                         DST Global, Temasek Holdings
# 1    Google Ventures, New Enterprise Associates, MP...
# 2    Sequoia Capital China, China Construction Bank...
# 3            China Cinda Asset Management, IDG Capital
# 4             German Media Pool, Seven Venture Capital
# 5    Clermont Group, Coltrane Asset Management, Tos...
# 6    Greylock Partners, North Bridge Venture Partne...
# 7                    Illumina, Celgene, Casdin Capital
# 8    Andreessen Horowitz, Khosla Ventures, Singapor...
# 9                                          GAM Holding
# 10                                      Iconiq Capital
# 11        Morningside Ventures, JD.com, Tiantu Capital
# 12    Tiantu Capital, Fortune Capital, Zhenghedao Fund
# 13   General Catalyst Partners, Andreessen Horowitz...
# 14        Caffeinated Capital, CRV, Founder Collective
# 15   Lerer Hippeau Ventures, T. Rowe Price, Tiger G...
# 16              Mithril, iNovia Capital, Foundry Group
# 17      Orient Hontai Capital, Webb Investment Network
# 18   Redpoint Ventures, QiMing Venture Partners, Ch...
# 19    8VC, Benchmark, Generation Investment Management
# 20   Toscafund Asset Management, Woodford Investmen...
# 21   Lux Capital, Mithril Capital Management, Highl...
# 22   Digital Sky Technologies, Piton Capital, DN Ca...
# 23   General Atlantic, Goldman Sachs, New Enterpris...
# 24   Insight Venture Partners, Lowercase Capital, P...
# 25                                       Warbug Pincus
# 26          RRE Ventures, Tiger Global, August Capital
# 27   Temasek Holdings, Charlotte Angel Partners, TP...
# 28   Banyan Capital, New Horizon Capital, IDG Capit...
# 29                      Woodford Investment Management
# ..                                                 ...
# 279                                      Rhone Capital
# 280  Bessemer Venture Partners, Qualcomm Ventures, ...
# 281  Accel Partners, Comcast Ventures, General Atla...
# 282  Gemini Israel Ventures, Insight Venture Partne...
# 283    BoxGroup, Felicis Ventures, First Round Capital
# 284                         Tencent, Morningside Group
# 285   T. Rowe Price, Benchmark Capital, SoftBank Group
# 286  Founders Fund, GGV Capital, Digital Sky Techno...
# 287  Hillhouse Capital Management, Altos Ventures, ...
# 288                     GGV Capital, ZhenFund, Tencent
# 289   Morningside Ventures, Capital Today, JOY Capital
# 290  Morningside Venture Capital, Foxconn Technolog...
# 291                                        Formation 8
# 292                       Co-Energy Finance, Grandland
# 293                                  Phoenix New Media
# 294  Source Code Capital, Meituan Dianping, Tencent...
# 295              Sequoia Capital China, Banyan Capital
# 296  Sequoia Capital China, Sina Weibo, Kleiner Per...
# 297  China Environmental Protection Industry, China...
# 298       Tencent Holdings, Warbug Pincus, IDG Capital
# 299  SV Angel, Institutional Venture Partners, Venrock
# 300              GSO Capital Partners, Franklin Square
# 301    K2 Ventures, Matrix Partners China, IDG Capital
# 302  Tencent Holdings, Sinovation Ventures, Qiming ...
# 303  Basepoint Ventures,Industry Ventures, and Inst...
# 304      Founders Fund, Khosla Ventures, Goldman Sachs
# 305                        Sequoia Capital, VY Capital
# 306  Sequoia Capital, Qualcomm Ventures, Emergence ...
# 307              AID Partners, Draper Fisher Jurvetson
# 308     Softbank Group, AME Cloud Ventures, SignalFire
#
# [309 rows x 6 columns]

# %%
merged = df.merge(gdf, left_on = 'Country', right_on = 'country')
gdf.plot()

# %%
buff = gpd.GeoDataFrame(merged)
buff.plot()

# %%
import json

#Read data to json
merged_json = json.loads(buff.to_json())

#Convert to str like object
json_data = json.dumps(merged_json)

# %%
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar
from bokeh.palettes import brewer

#Input GeoJSON source that contains features for plotting.
geosource = GeoJSONDataSource(geojson = json_data)

#Define a sequential multi-hue color palette.
palette = brewer['YlGnBu'][8]

#Reverse color order so that dark blue is highest obesity.
palette = palette[::-1]

#Instantiate LinearColorMapper that linearly maps numbers in a range, into a sequence of colors.
color_mapper = LinearColorMapper(palette = palette, low = 0, high = 40)

#Define custom tick labels for color bar.
tick_labels = {'0': '0%', '5': '5%', '10':'10%', '15':'15%', '20':'20%', '25':'25%', '30':'30%','35':'35%', '40': '>40%'}

#Create color bar. 
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 500, height = 20,
border_line_color=None,location = (0,0), orientation = 'horizontal', major_label_overrides = tick_labels)

#Create figure object.
p = figure(title = 'Share of adults who are obese, 2016', plot_height = 600 , plot_width = 950, toolbar_location = None)
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

#Add patch renderer to figure. 
p.patches('xs','ys', source = geosource,fill_color = {'field' :'Valuation', 'transform' : color_mapper},
          line_color = 'black', line_width = 0.25, fill_alpha = 1)

#Specify figure layout.
p.add_layout(color_bar, 'below')

#Display figure inline in Jupyter Notebook.
output_notebook()

#Display figure.
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e0e46661-4591-417d-b4a0-a4994fc1c290">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7e57575e-d399-46bc-ac68-9e2d8b77b1ab"></div>
# </div>
